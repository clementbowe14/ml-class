# %% [markdown]
# <a href="https://colab.research.google.com/github/clementbowe14/ml-class/blob/main/Bach.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

bach = pd.read_csv('/content/sample_data/bach.csv')
bach
# Out:
#      choral_ID  event_number    C  C#    D  D#    E    F  F#    G  G#    A  \
# 0     000106b_             1  YES  NO   NO  NO   NO  YES  NO   NO  NO  YES
# 1     000106b_             2  YES  NO   NO  NO  YES   NO  NO  YES  NO   NO
# 2     000106b_             3  YES  NO   NO  NO  YES   NO  NO  YES  NO   NO
# 3     000106b_             4  YES  NO   NO  NO   NO  YES  NO   NO  NO  YES
# 4     000106b_             5  YES  NO   NO  NO   NO  YES  NO   NO  NO  YES
# ...        ...           ...  ...  ..  ...  ..  ...  ...  ..  ...  ..  ...
# 5660  015505b_           105   NO  NO  YES  NO   NO   NO  NO  YES  NO   NO
# 5661  015505b_           106   NO  NO  YES  NO   NO   NO  NO  YES  NO  YES
# 5662  015505b_           107  YES  NO   NO  NO  YES   NO  NO  YES  NO   NO
# 5663  015505b_           108  YES  NO   NO  NO  YES   NO  NO  YES  NO   NO
# 5664  015505b_           109   NO  NO   NO  NO   NO  YES  NO   NO  NO  YES
#
#        A#   B bass  meter chord_label
# ...

# %%
bach = bach.drop(['choral_ID', 'event_number'], axis=1)
bach
# Out:
#         C  C#    D  D#    E    F  F#    G  G#    A   A#   B bass  meter  \
# 0     YES  NO   NO  NO   NO  YES  NO   NO  NO  YES   NO  NO    F      3
# 1     YES  NO   NO  NO  YES   NO  NO  YES  NO   NO   NO  NO    E      5
# 2     YES  NO   NO  NO  YES   NO  NO  YES  NO   NO   NO  NO    E      2
# 3     YES  NO   NO  NO   NO  YES  NO   NO  NO  YES   NO  NO    F      3
# 4     YES  NO   NO  NO   NO  YES  NO   NO  NO  YES   NO  NO    F      2
# ...   ...  ..  ...  ..  ...  ...  ..  ...  ..  ...  ...  ..  ...    ...
# 5660   NO  NO  YES  NO   NO   NO  NO  YES  NO   NO  YES  NO    G      4
# 5661   NO  NO  YES  NO   NO   NO  NO  YES  NO  YES   NO  NO    G      3
# 5662  YES  NO   NO  NO  YES   NO  NO  YES  NO   NO   NO  NO    C      5
# 5663  YES  NO   NO  NO  YES   NO  NO  YES  NO   NO  YES  NO    C      3
# 5664   NO  NO   NO  NO   NO  YES  NO   NO  NO  YES   NO  NO    F      4
#
#      chord_label
# 0            F_M
# 1            C_M
# 2            C_M
# 3            F_M
# ...

# %%
labels =
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-7e0bee9c9565> in <module>
#       1 notes = ['C',   'C#',   'D'     ,'D#'   ,'E',   'F','F#','G'    ,'G#'   ,'A', 'A#', 'B']
# ----> 2 bach[notes] = pd.get_dummies(bach[notes])
#       3 bach
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    3641             self._setitem_frame(key, value)
#    3642         elif isinstance(key, (Series, np.ndarray, list, Index)):
# -> 3643             self._setitem_array(key, value)
#    3644         elif isinstance(value, DataFrame):
#    3645             self._set_item_frame_value(key, value)
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/frame.py in _setitem_array(self, key, value)
#    3683
#    3684             if isinstance(value, DataFrame):
# -> 3685                 check_key_length(self.columns, key, value)
# ...
